# %% [markdown]
# # 每月更新dataset_list操作指南

# %% [markdown]
# 使用步骤：
# * 将全局变量DATE_FROM改成比上次更新时间提前几天，以确保检索不会遗漏，格式"YYYY/MM/DD"。例如，上次10月1日更新，则一个月后11月1日运行该notebook，更改DATE_FROM="2019/09/28"。（第一次用可以设置成"2019/10/01"，因为现有的list创建时间是2019/10/09）
#
# - 更改旧的数据集list的路径OLD_LIST_DIR。
#
# * 运行以下所有代码。最终生成新的数据集list在同目录下，文件名格式类似"pubmed_dataset_list_updated_20191101.csv"（时间由代码自动生成）。

# %%
from pymed import PubMed
import os
import pandas as pd
from Bio import Entrez
import time

OLD_LIST_DIR="pubmed_dataset_list_unique_new.csv"

NEW_LIST_DIR="pubmed_dataset_list_updated_"+time.strftime("%Y%m%d", time.localtime())+".csv"

DATE_FROM="2019/10/01"

ALLOWED_JOURNALS = [
    'Cancer Cell',
    'Cell',
    'Cell Stem Cell',
    'Cell Syst',
    'Elife',
    'Immunity',
    'Mol. Cell',
    'Nat Biomed Eng',
    'Nat Commun',
    'Nat. Cell Biol.',
    'Nat. Genet.',
    'Nat. Immunol.',
    'Nat. Med.',
    'Nat. Methods',
    'Nat. Neurosci.',
    'Nature',
    'Neuron',
    'Science',
    'Sci Immunol',
    'Sci Transl Med',
    'Cancer Discov'
]

# %% [markdown]
# 通过pubmed搜索获取需要增加的数据集，获取标题、期刊名、pubmedID。

# %%
"""
get titles and pubmed_id of single-cell related papers from pubmed

filter:
1. Allowed journals
2. Time 
    "The first description of single-cell transcriptome analysis based on a next-generation sequencing platform was published in 2009"
3. Keywords in title/abstract: single cell OR scRNA
"""

class PubMedAPI():
    """
    wrapper of PubMed API,
    based on the pymed package
    """
    def __init__(self):
        self.pubmed = PubMed(tool="MyTool", email="my@email.address")

    def get_multiple_article_info(self,
                                  query_string: str = "",
                                  max_results: int = 20,
                                  ):
        """
        :param query_string: string, query sentence; example:"single-cell[Title]"
        :param max_results: int, maximum results
        """
        def _construct_query_string_by_journal_and_time():
            """
            pre-construct query_string
            filter: allowed journals and time(DATE_FROM-present)
            """
            query_string_by_journal = '"[Journal] OR "'.join(ALLOWED_JOURNALS)
            query_string_by_journal = '("' + query_string_by_journal + '"[Journal]) AND '
            query_string_by_journal = query_string_by_journal + '(("'+DATE_FROM+'"[Date - Publication] : "3000"[Date - Publication])) AND '
            return query_string_by_journal

        # construct query string (add journal filter)
        query_string = _construct_query_string_by_journal_and_time() + query_string
        results = self.pubmed.query(query_string, max_results)

        title = list()
        journal = list()
        pubmed_id = list()

        for article in results:
            try:
                journal.append(article.journal)
            except AttributeError:
                continue
            # title[:-1:] can delete "." in the end of every title
            title.append(article.title[:-1:])
            # "splitlines()[0]" can deal with occasional format anomaly
            pubmed_id.append(article.pubmed_id.splitlines()[0])

        df = pd.DataFrame(data = {
            "title": title,
            "journal": journal,
            "pubmed_id": pubmed_id
            })

        return df

# %%
add_list=PubMedAPI().get_multiple_article_info("(single-cell[Title/Abstract] OR scRNA[Title/Abstract])",3000)

# %%
add_list
# Out:
#                                                 title  \
# 0   Single-cell proteomics reveals changes in expr...
# 1   Bayesian Inference of Allelic Inclusion Rates ...
# 2   Stress-Induced Metabolic Disorder in Periphera...
# 3   Landscape and Dynamics of Single Immune Cells ...
# 4   In vitro culture of cynomolgus monkey embryos ...
# 5   Dissecting primate early post-implantation dev...
# 6   Chronic Stress Induces Activity, Synaptic, and...
# 7   Transcriptional Basis of Mouse and Human Dendr...
# 8   The oomycete Lagenisma coscinodisci hijacks ho...
# 9   Ontogenic changes in hematopoietic hierarchy d...
# 10  A chemical probe of CARM1 alters epigenetic pl...
# 11  Biological process activity transformation of ...
# 12  Single-cell RNA-sequencing of herpes simplex v...
# 13      The geometry of masking in neural populations
# 14  Single-cell transcriptomic atlas of the human ...
# 15  Phase separation-deficient TDP43 remains funct...
# 16  Occurrence and repair of alkylating stress in ...
# 17  Correcting the Mean-Variance Dependency for Di...
# 18  Single-cell transcriptomes and whole-brain pro...
# 19  Heterogeneity in old fibroblasts is linked to ...
# 20  Single cell analysis reveals immune cell-adipo...
# 21  A multiscale signalling network map of innate ...
# 22  Single-Cell Analysis Reveals Regulatory Gene E...
# 23  Functional profiling of single CRISPR/Cas9-edi...
# 24  Multimodal Analysis of Cell Types in a Hypotha...
# 25  Generation of Blastocyst-like Structures from ...
# 26  Single-cell transcriptomics of human T cells r...
# 27  Organoid single-cell genomic atlas uncovers hu...
# 28  Transcriptional Atlas of Intestinal Immune Cel...
# 29  Multiplexed and single cell tracing of lipid m...
# ..                                                ...
# 42  Control of cytokinesis by β-adrenergic recepto...
# 43  Resolving the fibrotic niche of human liver ci...
# 44  SCALE method for single-cell ATAC-seq analysis...
# 45  Dissecting splicing decisions and cell-to-cell...
# 46  Stereotyped transcriptomic transformation of s...
# 47  Multiplex live single-cell transcriptional ana...
# 48  Single-cell immune landscape of human atherosc...
# 49  Exploring single-cell data with deep multitask...
# 50                            Locally instructed CXCR
# 51  Tumor Cell Biodiversity Drives Microenvironmen...
# 52  Cell Type Purification by Single-Cell Transcri...
# 53  Microglia Biology: One Century of Evolving Con...
# 54  Single cell transcriptome in aneuploidies reve...
# 55  Single-Cell RNA Sequencing Reveals a Developme...
# 56  Single-Cell Reconstruction of Emerging Populat...
# 57  Human Germline Cell Development: from the Pers...
# 58  Single-cell transcriptomic profiling of the ag...
# 59  Mitigating Antagonism between Transcription an...
# 60  Valid Post-clustering Differential Analysis fo...
# 61  Probabilistic cell-type assignment of single-c...
# 62  Simultaneous profiling of 3D genome structure ...
# 63  FRET-assisted photoactivation of flavoproteins...
# 64  Supervised classification enables rapid annota...
# 65     Supervised clustering for single-cell analysis
# 66  Complex Oscillatory Waves Emerging from Cortic...
# 67  CoBATCH for High-Throughput Single-Cell Epigen...
# 68  CRISPR Interference-Based Platform for Multimo...
# 69  Neuropeptide CGRP Limits Group 2 Innate Lympho...
# 70  Epigenomics and Single-Cell Sequencing Define ...
# 71  Stress-Induced Changes in Bone Marrow Stromal ...
#
#                            journal pubmed_id
# 0                            eLife  31682227
# 1                     Cell systems  31677971
# 2                             Cell  31675497
# 3                             Cell  31675496
# 4         Science (New York, N.Y.)  31672918
# 5         Science (New York, N.Y.)  31672917
# 6                           Neuron  31672263
# 7                             Cell  31668803
# 8            Nature communications  31666506
# 9                 Cancer discovery  31662298
# 10                           eLife  31657716
# 11           Nature communications  31653878
# 12           Nature communications  31653857
# 13           Nature communications  31653855
# 14           Nature communications  31653841
# 15           Nature communications  31653829
# 16           Nature communications  31649248
# 17                    Cell systems  31647917
# 18                           eLife  31647409
# 19                          Nature  31645721
# 20                           eLife  31644425
# 21           Nature communications  31641119
# 22                    Cell systems  31629685
# 23           Nature communications  31628330
# 24                            Cell  31626771
# 25                            Cell  31626770
# 26           Nature communications  31624246
# 27                          Nature  31619793
# 28                        Immunity  31618654
# 29                  Nature methods  31611692
# ..                             ...       ...
# 42  Science translational medicine  31597755
# 43                          Nature  31597160
# 44           Nature communications  31594952
# 45           Nature communications  31594945
# 46                           eLife  31592768
# 47                           eLife  31591966
# 48                 Nature medicine  31591603
# 49                  Nature methods  31591579
# 50               Nature immunology  31591573
# 51                     Cancer cell  31588021
# 52                            Cell  31585086
# 53                            Cell  31585077
# 54           Nature communications  31582743
# 55                Cancer discovery  31575563
# 56                            Cell  31564455
# 57                  Molecular cell  31563431
# 58             Nature neuroscience  31551601
# 59                  Cell stem cell  31523028
# 60                    Cell systems  31521605
# 61                  Nature methods  31501550
# 62                  Nature methods  31501549
# 63                  Nature methods  31501546
# 64                  Nature methods  31501545
# 65                  Nature methods  31501544
# 66                  Cell stem cell  31474560
# 67                  Molecular cell  31471188
# 68                          Neuron  31422865
# 69                        Immunity  31353223
# 70                Cancer discovery  31345789
# 71                  Cell stem cell  31279774
#
# [72 rows x 3 columns]

# %% [markdown]
# 下面根据pubmed_id获得每个数据集的GSE号。

# %%
def getGSEFromPubmedID(pubmed_id:str="") ->str:
    try:
        handle =Entrez.elink(dbfrom = 'pubmed', id = pubmed_id, db = 'gds')
        link_results = Entrez.read(handle)
        id_list=list()
        for item in link_results[0]["LinkSetDb"][0]["Link"]:
            id_list.append("GSE"+item['Id'][3::])
        id_list_total = "_".join(id_list)
        return id_list_total
    except:
        return "notAvailable"

# %% [markdown]
# 下面这块代码会报"Email address is not specified."的warning，无视即可。

# %%
gseID=list()
for pubmed_id in add_list["pubmed_id"]:
    gseID.append(getGSEFromPubmedID(pubmed_id))
add_list["gseID"]=gseID
# Out:
# /home/biodb/.local/lib/python3.6/site-packages/Bio/Entrez/__init__.py:606: UserWarning:
# Email address is not specified.
#
# To make use of NCBI's E-utilities, NCBI requires you to specify your
# email address with each request.  As an example, if your email address
# is A.N.Other@example.com, you can specify it as follows:
#    from Bio import Entrez
#    Entrez.email = 'A.N.Other@example.com'
# In case of excessive usage of the E-utilities, NCBI will attempt to contact
# a user at the email address provided before blocking access to the
# E-utilities.
#   E-utilities.""", UserWarning)

# %%
add_list
# Out:
#                                                 title  \
# 0   Single-cell proteomics reveals changes in expr...
# 1   Bayesian Inference of Allelic Inclusion Rates ...
# 2   Stress-Induced Metabolic Disorder in Periphera...
# 3   Landscape and Dynamics of Single Immune Cells ...
# 4   In vitro culture of cynomolgus monkey embryos ...
# 5   Dissecting primate early post-implantation dev...
# 6   Chronic Stress Induces Activity, Synaptic, and...
# 7   Transcriptional Basis of Mouse and Human Dendr...
# 8   The oomycete Lagenisma coscinodisci hijacks ho...
# 9   Ontogenic changes in hematopoietic hierarchy d...
# 10  A chemical probe of CARM1 alters epigenetic pl...
# 11  Biological process activity transformation of ...
# 12  Single-cell RNA-sequencing of herpes simplex v...
# 13      The geometry of masking in neural populations
# 14  Single-cell transcriptomic atlas of the human ...
# 15  Phase separation-deficient TDP43 remains funct...
# 16  Occurrence and repair of alkylating stress in ...
# 17  Correcting the Mean-Variance Dependency for Di...
# 18  Single-cell transcriptomes and whole-brain pro...
# 19  Heterogeneity in old fibroblasts is linked to ...
# 20  Single cell analysis reveals immune cell-adipo...
# 21  A multiscale signalling network map of innate ...
# 22  Single-Cell Analysis Reveals Regulatory Gene E...
# 23  Functional profiling of single CRISPR/Cas9-edi...
# 24  Multimodal Analysis of Cell Types in a Hypotha...
# 25  Generation of Blastocyst-like Structures from ...
# 26  Single-cell transcriptomics of human T cells r...
# 27  Organoid single-cell genomic atlas uncovers hu...
# 28  Transcriptional Atlas of Intestinal Immune Cel...
# 29  Multiplexed and single cell tracing of lipid m...
# ..                                                ...
# 42  Control of cytokinesis by β-adrenergic recepto...
# 43  Resolving the fibrotic niche of human liver ci...
# 44  SCALE method for single-cell ATAC-seq analysis...
# 45  Dissecting splicing decisions and cell-to-cell...
# 46  Stereotyped transcriptomic transformation of s...
# 47  Multiplex live single-cell transcriptional ana...
# 48  Single-cell immune landscape of human atherosc...
# 49  Exploring single-cell data with deep multitask...
# 50                            Locally instructed CXCR
# 51  Tumor Cell Biodiversity Drives Microenvironmen...
# 52  Cell Type Purification by Single-Cell Transcri...
# 53  Microglia Biology: One Century of Evolving Con...
# 54  Single cell transcriptome in aneuploidies reve...
# 55  Single-Cell RNA Sequencing Reveals a Developme...
# 56  Single-Cell Reconstruction of Emerging Populat...
# 57  Human Germline Cell Development: from the Pers...
# 58  Single-cell transcriptomic profiling of the ag...
# 59  Mitigating Antagonism between Transcription an...
# 60  Valid Post-clustering Differential Analysis fo...
# 61  Probabilistic cell-type assignment of single-c...
# 62  Simultaneous profiling of 3D genome structure ...
# 63  FRET-assisted photoactivation of flavoproteins...
# 64  Supervised classification enables rapid annota...
# 65     Supervised clustering for single-cell analysis
# 66  Complex Oscillatory Waves Emerging from Cortic...
# 67  CoBATCH for High-Throughput Single-Cell Epigen...
# 68  CRISPR Interference-Based Platform for Multimo...
# 69  Neuropeptide CGRP Limits Group 2 Innate Lympho...
# 70  Epigenomics and Single-Cell Sequencing Define ...
# 71  Stress-Induced Changes in Bone Marrow Stromal ...
#
#                            journal pubmed_id  \
# 0                            eLife  31682227
# 1                     Cell systems  31677971
# 2                             Cell  31675497
# 3                             Cell  31675496
# 4         Science (New York, N.Y.)  31672918
# 5         Science (New York, N.Y.)  31672917
# 6                           Neuron  31672263
# 7                             Cell  31668803
# 8            Nature communications  31666506
# 9                 Cancer discovery  31662298
# 10                           eLife  31657716
# 11           Nature communications  31653878
# 12           Nature communications  31653857
# 13           Nature communications  31653855
# 14           Nature communications  31653841
# 15           Nature communications  31653829
# 16           Nature communications  31649248
# 17                    Cell systems  31647917
# 18                           eLife  31647409
# 19                          Nature  31645721
# 20                           eLife  31644425
# 21           Nature communications  31641119
# 22                    Cell systems  31629685
# 23           Nature communications  31628330
# 24                            Cell  31626771
# 25                            Cell  31626770
# 26           Nature communications  31624246
# 27                          Nature  31619793
# 28                        Immunity  31618654
# 29                  Nature methods  31611692
# ..                             ...       ...
# 42  Science translational medicine  31597755
# 43                          Nature  31597160
# 44           Nature communications  31594952
# 45           Nature communications  31594945
# 46                           eLife  31592768
# 47                           eLife  31591966
# 48                 Nature medicine  31591603
# 49                  Nature methods  31591579
# 50               Nature immunology  31591573
# 51                     Cancer cell  31588021
# 52                            Cell  31585086
# 53                            Cell  31585077
# 54           Nature communications  31582743
# 55                Cancer discovery  31575563
# 56                            Cell  31564455
# 57                  Molecular cell  31563431
# 58             Nature neuroscience  31551601
# 59                  Cell stem cell  31523028
# 60                    Cell systems  31521605
# 61                  Nature methods  31501550
# 62                  Nature methods  31501549
# 63                  Nature methods  31501546
# 64                  Nature methods  31501545
# 65                  Nature methods  31501544
# 66                  Cell stem cell  31474560
# 67                  Molecular cell  31471188
# 68                          Neuron  31422865
# 69                        Immunity  31353223
# 70                Cancer discovery  31345789
# 71                  Cell stem cell  31279774
#
#                                                 gseID
# 0                                        notAvailable
# 1                                        notAvailable
# 2                                        notAvailable
# 3                                        notAvailable
# 4                                           GSE030114
# 5                                        notAvailable
# 6                                        notAvailable
# 7                                        notAvailable
# 8                                        notAvailable
# 9                                        notAvailable
# 10                                       notAvailable
# 11                                       notAvailable
# 12                                          GSE023782
# 13                                       notAvailable
# 14                      GSE037847_GSE037846_GSE037537
# 15                                       notAvailable
# 16                                          GSE036733
# 17                                       notAvailable
# 18                                          GSE035132
# 19                                       notAvailable
# 20                                       notAvailable
# 21                                       notAvailable
# 22                                       notAvailable
# 23                                       notAvailable
# 24                                       notAvailable
# 25                                       notAvailable
# 26                                          GSE026030
# 27                                       notAvailable
# 28                                          GSE024880
# 29                                       notAvailable
# ..                                                ...
# 42                                       notAvailable
# 43                                          GSE036103
# 44                                       notAvailable
# 45                                          GSE032064
# 46                                          GSE031272
# 47                                       notAvailable
# 48                                       notAvailable
# 49                                       notAvailable
# 50                                       notAvailable
# 51                                          GSE025449
# 52                                          GSE012438
# 53                                       notAvailable
# 54                                GSE035500_GSE023028
# 55                                       notAvailable
# 56                                       notAvailable
# 57                                       notAvailable
# 58                                          GSE029788
# 59                                       notAvailable
# 60                                       notAvailable
# 61                                       notAvailable
# 62                                GSE030711_GSE024391
# 63                                       notAvailable
# 64                                       notAvailable
# 65                                       notAvailable
# 66                                       notAvailable
# 67  GSE032846_GSE032844_GSE029335_GSE029333_GSE029...
# 68                                       notAvailable
# 69                                          GSE031996
# 70                      GSE033785_GSE033706_GSE033704
# 71                                          GSE031305
#
# [71 rows x 4 columns]

# %%
old_list = pd.read_csv(OLD_LIST_DIR,  index_col=0)

# %%
old_list
# Out:
#                                                   title  \
# X1
# 0     A Pooled Single-Cell Genetic Screen Identifies...
# 1     Heterogeneity Of Human Bone Marrow And Blood N...
# 2     Single-Cell Transcriptomics Reveals Multi-Step...
# 4     Complex Oscillatory Waves Emerging From Cortic...
# 6     Single-Cell Analysis Of Crohn'S Disease Lesion...
# 7     Data Denoising With Transfer Learning In Singl...
# 8                                    Position Β57 Of I-
# 12    Identification Of Somatic Mutations In Single ...
# 15    Liquid Biopsy-Based Single-Cell Metabolic Phen...
# 18    Single-Cell Profiling Guided Combinatorial Imm...
# 22    B1 Oligomerization Regulates Pml Nuclear Body ...
# 23    The Malaria Cell Atlas: Single Parasite Transc...
# 25    Conserved Cell Types With Divergent Features I...
# 26    Reconstituting The Transcriptome And Dna Methy...
# 27    Metabolic Landscape Of The Tumor Microenvironm...
# 29    Molecular Mechanisms Of Lineage Decisions In M...
# 30    Mapping Histone Modifications In Low Cell Numb...
# 34    Defining The Identity And Dynamics Of Adult Ga...
# 37    Single Cell Transcriptome Analysis Of Developi...
# 41    Dissecting The Heterogeneity Of Denv Vaccine-E...
# 42    A General Approach For Detecting Expressed Mut...
# 47                    A Dream Of Single-Cell Proteomics
# 48    An Nfil3-Zeb2-Id2 Pathway Imposes Irf8 Enhance...
# 49    Single-Cell Dna Replication Profiling Identifi...
# 56    Exploring Genetic Interaction Manifolds Constr...
# 66    A Single-Cell Window Into Pancreas Cancer Fibr...
# 70    Cell-Type-Specific Resolution Epigenetics With...
# 71    Gene Expression Atlas Of A Developing Tissue B...
# 78    The Transcription Factor Tcf-1 Enforces Commit...
# 79    Single-Cell Cas-Seq Reveals A Class Of Short P...
# ...                                                 ...
# 1739  Condensin- And Replication-Mediated Bacterial ...
# 1740  High-Throughput Pairing Of T Cell Receptor Α A...
# 1741  Single-Cell Messenger Rna Sequencing Reveals R...
# 1742  Monitoring Mitochondrial Pyruvate Carrier Acti...
# 1743  Single-Cell Transcriptome Analysis Reveals Coo...
# 1744  Aire Controls Gene Expression In The Thymic Ep...
# 1745  Single-Cell Transcriptomics Reveals A Populati...
# 1747  Human Nk Cell Repertoire Diversity Reflects Im...
# 1748  Single-Cell Mrna Profiling Reveals Cell-Type-S...
# 1749  Matching Cell Type To Function In Cortical Cir...
# 1750  Delineating Cancer Evolution With Single-Cell ...
# 1751  Preconditioning Allows Engraftment Of Mouse An...
# 1752  Photoswitchable Inhibitors Of Microtubule Dyna...
# 1753  Two Routes To Senescence Revealed By Real-Time...
# 1754  Prediction Model For Aneuploidy In Early Human...
# 1755  Probing The Target Search Of Dna-Binding Prote...
# 1756  Multitarget Super-Resolution Microscopy With H...
# 1757  Presynaptic Networks. Single-Cell-Initiated Mo...
# 1758  Eye-Like Ocelloids Are Built From Different En...
# 1759  Digital Microfluidic Immunocytochemistry In Si...
# 1760  Single-Cell Magnetic Imaging Using A Quantum D...
# 1761  Data-Driven Phenotypic Dissection Of Aml Revea...
# 1762    Linking Micronuclei To Chromosome Fragmentation
# 1763  Avian Models For Human Cognitive Neuroscience:...
# 1764  Single-Cell Chromatin Accessibility Reveals Pr...
# 1765  Single Molecule-Level Detection And Long Read-...
# 1766  Identification Of Cdc1- And Cdc2-Committed Dc ...
# 1767  Tip Cell-Specific Requirement For An Atypical ...
# 1768  Bringing Blood Stem Cell Phenotype, Genotype, ...
# 1769  The Transcriptome And Dna Methylome Landscapes...
#
#                              journal  pubmed_id                          gseID
# X1
# 0                    Nature genetics   31477929                   notAvailable
# 1              Nature communications   31477722                      GSE130430
# 2              Nature communications   31477698                      GSE122743
# 4                     Cell stem cell   31474560                   notAvailable
# 6                               Cell   31474370                   notAvailable
# 7                     Nature methods   31471617                   notAvailable
# 8                 Science immunology   31471352                   notAvailable
# 12             Nature communications   31467286                   notAvailable
# 15             Nature communications   31451693                   notAvailable
# 18             Nature communications   31444334                      GSE122336
# 22             Nature communications   31439836                   notAvailable
# 23          Science (New York, N.Y.)   31439762                   notAvailable
# 25                            Nature   31435019                   notAvailable
# 26                            Nature   31435013                      GSE109555
# 27             Nature communications   31434891                   notAvailable
# 29                 Nature immunology   31431722                   notAvailable
# 30             Nature communications   31431618                      GSE125971
# 34                    Cell stem cell   31422913                   notAvailable
# 37             Nature communications   31420539                      GSE126480
# 41             Nature communications   31413301                      GSE132950
# 42             Nature communications   31413257                   notAvailable
# 47                    Nature methods   31406385                   notAvailable
# 48                 Nature immunology   31406377                   notAvailable
# 49                   Nature genetics   31406346                   notAvailable
# 56          Science (New York, N.Y.)   31395745                   notAvailable
# 66                  Cancer discovery   31371323                   notAvailable
# 70             Nature communications   31366909                      GSE131989
# 71                    Nature methods   31363221                      GSE127832
# 78                 Nature immunology   31358996                      GSE128483
# 79             Nature communications   31358756                      GSE095218
# ...                              ...        ...                            ...
# 1739                  Molecular cell   26295962                   notAvailable
# 1740  Science translational medicine   26290413                   notAvailable
# 1741                          Nature   26287467                      GSE062270
# 1742                  Molecular cell   26253029                   notAvailable
# 1743               Nature immunology   26237553                   notAvailable
# 1744               Nature immunology   26237550                      GSE070798
# 1745                  Cell stem cell   26235341                      GSE067833
# 1747  Science translational medicine   26203083                   notAvailable
# 1748                          Neuron   26182417                   notAvailable
# 1749                          Neuron   26182411                   notAvailable
# 1750  Science translational medicine   26180099                   notAvailable
# 1751                 Nature medicine   26168294                   notAvailable
# 1752                            Cell   26165941                   notAvailable
# 1753           Nature communications   26158780                   notAvailable
# 1754           Nature communications   26151134                   notAvailable
# 1755           Nature communications   26151127                   notAvailable
# 1756                  Nature methods   26147917                   notAvailable
# 1757        Science (New York, N.Y.)   26138975                   notAvailable
# 1758                          Nature   26131935                   notAvailable
# 1759           Nature communications   26104298                   notAvailable
# 1760                  Nature methods   26098019                   notAvailable
# 1761                            Cell   26095251                   notAvailable
# 1762                            Cell   26091034                   notAvailable
# 1763                          Neuron   26087161                   notAvailable
# 1764                          Nature   26083756                      GSE065360
# 1765           Nature communications   26074426                   notAvailable
# 1766               Nature immunology   26054720  GSE060783_GSE060782_GSE060781
# 1767                           eLife   26051822                   notAvailable
# 1768                  Cell stem cell   26046754                   notAvailable
# 1769                            Cell   26046443                      GSE063818
#
# [1381 rows x 4 columns]

# %% [markdown]
# 过滤掉已使用的GSE号，如果一篇文章的所有GSE号均已使用，将整篇文章过滤掉。

# %%
used_gseID=set()
for each in old_list["gseID"]:
    used_gseID=used_gseID.union(set(each.split("_")))
used_gseID.discard("notAvailable")

add_gse=add_list["gseID"]
processed_add_gse=list()
for each in add_gse:
    if each=="notAvailable":
        processed_add_gse.append(each)
    else:
        processed_each=[i for i in list(each.split("_")) if not i in used_gseID]
        used_gseID=used_gseID.union(set(processed_each))  # update used_gseID
        processed_add_gse.append("_".join(processed_each))

add_list["gseID"]=processed_add_gse
add_list=add_list[add_list["gseID"]!=""]
add_list
# Out:
#                                                 title  \
# 0   Single-cell proteomics reveals changes in expr...
# 1   Bayesian Inference of Allelic Inclusion Rates ...
# 2   Stress-Induced Metabolic Disorder in Periphera...
# 3   Landscape and Dynamics of Single Immune Cells ...
# 4   In vitro culture of cynomolgus monkey embryos ...
# 5   Dissecting primate early post-implantation dev...
# 6   Chronic Stress Induces Activity, Synaptic, and...
# 7   Transcriptional Basis of Mouse and Human Dendr...
# 8   The oomycete Lagenisma coscinodisci hijacks ho...
# 9   Ontogenic changes in hematopoietic hierarchy d...
# 10  A chemical probe of CARM1 alters epigenetic pl...
# 11  Biological process activity transformation of ...
# 12  Single-cell RNA-sequencing of herpes simplex v...
# 13      The geometry of masking in neural populations
# 14  Single-cell transcriptomic atlas of the human ...
# 15  Phase separation-deficient TDP43 remains funct...
# 16  Occurrence and repair of alkylating stress in ...
# 17  Correcting the Mean-Variance Dependency for Di...
# 18  Single-cell transcriptomes and whole-brain pro...
# 19  Heterogeneity in old fibroblasts is linked to ...
# 20  Single cell analysis reveals immune cell-adipo...
# 21  A multiscale signalling network map of innate ...
# 22  Single-Cell Analysis Reveals Regulatory Gene E...
# 23  Functional profiling of single CRISPR/Cas9-edi...
# 24  Multimodal Analysis of Cell Types in a Hypotha...
# 25  Generation of Blastocyst-like Structures from ...
# 26  Single-cell transcriptomics of human T cells r...
# 27  Organoid single-cell genomic atlas uncovers hu...
# 28  Transcriptional Atlas of Intestinal Immune Cel...
# 29  Multiplexed and single cell tracing of lipid m...
# ..                                                ...
# 42  Control of cytokinesis by β-adrenergic recepto...
# 43  Resolving the fibrotic niche of human liver ci...
# 44  SCALE method for single-cell ATAC-seq analysis...
# 45  Dissecting splicing decisions and cell-to-cell...
# 46  Stereotyped transcriptomic transformation of s...
# 47  Multiplex live single-cell transcriptional ana...
# 48  Single-cell immune landscape of human atherosc...
# 49  Exploring single-cell data with deep multitask...
# 50                            Locally instructed CXCR
# 51  Tumor Cell Biodiversity Drives Microenvironmen...
# 52  Cell Type Purification by Single-Cell Transcri...
# 53  Microglia Biology: One Century of Evolving Con...
# 54  Single cell transcriptome in aneuploidies reve...
# 55  Single-Cell RNA Sequencing Reveals a Developme...
# 56  Single-Cell Reconstruction of Emerging Populat...
# 57  Human Germline Cell Development: from the Pers...
# 58  Single-cell transcriptomic profiling of the ag...
# 59  Mitigating Antagonism between Transcription an...
# 60  Valid Post-clustering Differential Analysis fo...
# 61  Probabilistic cell-type assignment of single-c...
# 62  Simultaneous profiling of 3D genome structure ...
# 63  FRET-assisted photoactivation of flavoproteins...
# 64  Supervised classification enables rapid annota...
# 65     Supervised clustering for single-cell analysis
# 66  Complex Oscillatory Waves Emerging from Cortic...
# 67  CoBATCH for High-Throughput Single-Cell Epigen...
# 68  CRISPR Interference-Based Platform for Multimo...
# 69  Neuropeptide CGRP Limits Group 2 Innate Lympho...
# 70  Epigenomics and Single-Cell Sequencing Define ...
# 71  Stress-Induced Changes in Bone Marrow Stromal ...
#
#                            journal pubmed_id  \
# 0                            eLife  31682227
# 1                     Cell systems  31677971
# 2                             Cell  31675497
# 3                             Cell  31675496
# 4         Science (New York, N.Y.)  31672918
# 5         Science (New York, N.Y.)  31672917
# 6                           Neuron  31672263
# 7                             Cell  31668803
# 8            Nature communications  31666506
# 9                 Cancer discovery  31662298
# 10                           eLife  31657716
# 11           Nature communications  31653878
# 12           Nature communications  31653857
# 13           Nature communications  31653855
# 14           Nature communications  31653841
# 15           Nature communications  31653829
# 16           Nature communications  31649248
# 17                    Cell systems  31647917
# 18                           eLife  31647409
# 19                          Nature  31645721
# 20                           eLife  31644425
# 21           Nature communications  31641119
# 22                    Cell systems  31629685
# 23           Nature communications  31628330
# 24                            Cell  31626771
# 25                            Cell  31626770
# 26           Nature communications  31624246
# 27                          Nature  31619793
# 28                        Immunity  31618654
# 29                  Nature methods  31611692
# ..                             ...       ...
# 42  Science translational medicine  31597755
# 43                          Nature  31597160
# 44           Nature communications  31594952
# 45           Nature communications  31594945
# 46                           eLife  31592768
# 47                           eLife  31591966
# 48                 Nature medicine  31591603
# 49                  Nature methods  31591579
# 50               Nature immunology  31591573
# 51                     Cancer cell  31588021
# 52                            Cell  31585086
# 53                            Cell  31585077
# 54           Nature communications  31582743
# 55                Cancer discovery  31575563
# 56                            Cell  31564455
# 57                  Molecular cell  31563431
# 58             Nature neuroscience  31551601
# 59                  Cell stem cell  31523028
# 60                    Cell systems  31521605
# 61                  Nature methods  31501550
# 62                  Nature methods  31501549
# 63                  Nature methods  31501546
# 64                  Nature methods  31501545
# 65                  Nature methods  31501544
# 66                  Cell stem cell  31474560
# 67                  Molecular cell  31471188
# 68                          Neuron  31422865
# 69                        Immunity  31353223
# 70                Cancer discovery  31345789
# 71                  Cell stem cell  31279774
#
#                                                 gseID
# 0                                        notAvailable
# 1                                        notAvailable
# 2                                        notAvailable
# 3                                        notAvailable
# 4                                           GSE030114
# 5                                        notAvailable
# 6                                        notAvailable
# 7                                        notAvailable
# 8                                        notAvailable
# 9                                        notAvailable
# 10                                       notAvailable
# 11                                       notAvailable
# 12                                          GSE023782
# 13                                       notAvailable
# 14                      GSE037847_GSE037846_GSE037537
# 15                                       notAvailable
# 16                                          GSE036733
# 17                                       notAvailable
# 18                                          GSE035132
# 19                                       notAvailable
# 20                                       notAvailable
# 21                                       notAvailable
# 22                                       notAvailable
# 23                                       notAvailable
# 24                                       notAvailable
# 25                                       notAvailable
# 26                                          GSE026030
# 27                                       notAvailable
# 28                                          GSE024880
# 29                                       notAvailable
# ..                                                ...
# 42                                       notAvailable
# 43                                          GSE036103
# 44                                       notAvailable
# 45                                          GSE032064
# 46                                          GSE031272
# 47                                       notAvailable
# 48                                       notAvailable
# 49                                       notAvailable
# 50                                       notAvailable
# 51                                          GSE025449
# 52                                          GSE012438
# 53                                       notAvailable
# 54                                GSE035500_GSE023028
# 55                                       notAvailable
# 56                                       notAvailable
# 57                                       notAvailable
# 58                                          GSE029788
# 59                                       notAvailable
# 60                                       notAvailable
# 61                                       notAvailable
# 62                                GSE030711_GSE024391
# 63                                       notAvailable
# 64                                       notAvailable
# 65                                       notAvailable
# 66                                       notAvailable
# 67  GSE032846_GSE032844_GSE029335_GSE029333_GSE029...
# 68                                       notAvailable
# 69                                          GSE031996
# 70                      GSE033785_GSE033706_GSE033704
# 71                                          GSE031305
#
# [71 rows x 4 columns]

# %% [markdown]
# 下面通过将待增加的数据集和旧数据集list合并并根据pubmed id去重，得到新的数据集list。

# %%
new_list=old_list.append(add_list)
new_list
# Out:
#                                                 title  \
# 0   A Pooled Single-Cell Genetic Screen Identifies...
# 1   Heterogeneity Of Human Bone Marrow And Blood N...
# 2   Single-Cell Transcriptomics Reveals Multi-Step...
# 4   Complex Oscillatory Waves Emerging From Cortic...
# 6   Single-Cell Analysis Of Crohn'S Disease Lesion...
# 7   Data Denoising With Transfer Learning In Singl...
# 8                                  Position Β57 Of I-
# 12  Identification Of Somatic Mutations In Single ...
# 15  Liquid Biopsy-Based Single-Cell Metabolic Phen...
# 18  Single-Cell Profiling Guided Combinatorial Imm...
# 22  B1 Oligomerization Regulates Pml Nuclear Body ...
# 23  The Malaria Cell Atlas: Single Parasite Transc...
# 25  Conserved Cell Types With Divergent Features I...
# 26  Reconstituting The Transcriptome And Dna Methy...
# 27  Metabolic Landscape Of The Tumor Microenvironm...
# 29  Molecular Mechanisms Of Lineage Decisions In M...
# 30  Mapping Histone Modifications In Low Cell Numb...
# 34  Defining The Identity And Dynamics Of Adult Ga...
# 37  Single Cell Transcriptome Analysis Of Developi...
# 41  Dissecting The Heterogeneity Of Denv Vaccine-E...
# 42  A General Approach For Detecting Expressed Mut...
# 47                  A Dream Of Single-Cell Proteomics
# 48  An Nfil3-Zeb2-Id2 Pathway Imposes Irf8 Enhance...
# 49  Single-Cell Dna Replication Profiling Identifi...
# 56  Exploring Genetic Interaction Manifolds Constr...
# 66  A Single-Cell Window Into Pancreas Cancer Fibr...
# 70  Cell-Type-Specific Resolution Epigenetics With...
# 71  Gene Expression Atlas Of A Developing Tissue B...
# 78  The Transcription Factor Tcf-1 Enforces Commit...
# 79  Single-Cell Cas-Seq Reveals A Class Of Short P...
# ..                                                ...
# 42  Control of cytokinesis by β-adrenergic recepto...
# 43  Resolving the fibrotic niche of human liver ci...
# 44  SCALE method for single-cell ATAC-seq analysis...
# 45  Dissecting splicing decisions and cell-to-cell...
# 46  Stereotyped transcriptomic transformation of s...
# 47  Multiplex live single-cell transcriptional ana...
# 48  Single-cell immune landscape of human atherosc...
# 49  Exploring single-cell data with deep multitask...
# 50                            Locally instructed CXCR
# 51  Tumor Cell Biodiversity Drives Microenvironmen...
# 52  Cell Type Purification by Single-Cell Transcri...
# 53  Microglia Biology: One Century of Evolving Con...
# 54  Single cell transcriptome in aneuploidies reve...
# 55  Single-Cell RNA Sequencing Reveals a Developme...
# 56  Single-Cell Reconstruction of Emerging Populat...
# 57  Human Germline Cell Development: from the Pers...
# 58  Single-cell transcriptomic profiling of the ag...
# 59  Mitigating Antagonism between Transcription an...
# 60  Valid Post-clustering Differential Analysis fo...
# 61  Probabilistic cell-type assignment of single-c...
# 62  Simultaneous profiling of 3D genome structure ...
# 63  FRET-assisted photoactivation of flavoproteins...
# 64  Supervised classification enables rapid annota...
# 65     Supervised clustering for single-cell analysis
# 66  Complex Oscillatory Waves Emerging from Cortic...
# 67  CoBATCH for High-Throughput Single-Cell Epigen...
# 68  CRISPR Interference-Based Platform for Multimo...
# 69  Neuropeptide CGRP Limits Group 2 Innate Lympho...
# 70  Epigenomics and Single-Cell Sequencing Define ...
# 71  Stress-Induced Changes in Bone Marrow Stromal ...
#
#                            journal pubmed_id  \
# 0                  Nature genetics  31477929
# 1            Nature communications  31477722
# 2            Nature communications  31477698
# 4                   Cell stem cell  31474560
# 6                             Cell  31474370
# 7                   Nature methods  31471617
# 8               Science immunology  31471352
# 12           Nature communications  31467286
# 15           Nature communications  31451693
# 18           Nature communications  31444334
# 22           Nature communications  31439836
# 23        Science (New York, N.Y.)  31439762
# 25                          Nature  31435019
# 26                          Nature  31435013
# 27           Nature communications  31434891
# 29               Nature immunology  31431722
# 30           Nature communications  31431618
# 34                  Cell stem cell  31422913
# 37           Nature communications  31420539
# 41           Nature communications  31413301
# 42           Nature communications  31413257
# 47                  Nature methods  31406385
# 48               Nature immunology  31406377
# 49                 Nature genetics  31406346
# 56        Science (New York, N.Y.)  31395745
# 66                Cancer discovery  31371323
# 70           Nature communications  31366909
# 71                  Nature methods  31363221
# 78               Nature immunology  31358996
# 79           Nature communications  31358756
# ..                             ...       ...
# 42  Science translational medicine  31597755
# 43                          Nature  31597160
# 44           Nature communications  31594952
# 45           Nature communications  31594945
# 46                           eLife  31592768
# 47                           eLife  31591966
# 48                 Nature medicine  31591603
# 49                  Nature methods  31591579
# 50               Nature immunology  31591573
# 51                     Cancer cell  31588021
# 52                            Cell  31585086
# 53                            Cell  31585077
# 54           Nature communications  31582743
# 55                Cancer discovery  31575563
# 56                            Cell  31564455
# 57                  Molecular cell  31563431
# 58             Nature neuroscience  31551601
# 59                  Cell stem cell  31523028
# 60                    Cell systems  31521605
# 61                  Nature methods  31501550
# 62                  Nature methods  31501549
# 63                  Nature methods  31501546
# 64                  Nature methods  31501545
# 65                  Nature methods  31501544
# 66                  Cell stem cell  31474560
# 67                  Molecular cell  31471188
# 68                          Neuron  31422865
# 69                        Immunity  31353223
# 70                Cancer discovery  31345789
# 71                  Cell stem cell  31279774
#
#                                                 gseID
# 0                                        notAvailable
# 1                                           GSE130430
# 2                                           GSE122743
# 4                                        notAvailable
# 6                                        notAvailable
# 7                                        notAvailable
# 8                                        notAvailable
# 12                                       notAvailable
# 15                                       notAvailable
# 18                                          GSE122336
# 22                                       notAvailable
# 23                                       notAvailable
# 25                                       notAvailable
# 26                                          GSE109555
# 27                                       notAvailable
# 29                                       notAvailable
# 30                                          GSE125971
# 34                                       notAvailable
# 37                                          GSE126480
# 41                                          GSE132950
# 42                                       notAvailable
# 47                                       notAvailable
# 48                                       notAvailable
# 49                                       notAvailable
# 56                                       notAvailable
# 66                                       notAvailable
# 70                                          GSE131989
# 71                                          GSE127832
# 78                                          GSE128483
# 79                                          GSE095218
# ..                                                ...
# 42                                       notAvailable
# 43                                          GSE036103
# 44                                       notAvailable
# 45                                          GSE032064
# 46                                          GSE031272
# 47                                       notAvailable
# 48                                       notAvailable
# 49                                       notAvailable
# 50                                       notAvailable
# 51                                          GSE025449
# 52                                          GSE012438
# 53                                       notAvailable
# 54                                GSE035500_GSE023028
# 55                                       notAvailable
# 56                                       notAvailable
# 57                                       notAvailable
# 58                                          GSE029788
# 59                                       notAvailable
# 60                                       notAvailable
# 61                                       notAvailable
# 62                                GSE030711_GSE024391
# 63                                       notAvailable
# 64                                       notAvailable
# 65                                       notAvailable
# 66                                       notAvailable
# 67  GSE032846_GSE032844_GSE029335_GSE029333_GSE029...
# 68                                       notAvailable
# 69                                          GSE031996
# 70                      GSE033785_GSE033706_GSE033704
# 71                                          GSE031305
#
# [1452 rows x 4 columns]

# %%
new_list.drop_duplicates(subset="pubmed_id", keep='first', inplace=True)
new_list.index=range(0,len(new_list))
new_list
# Out:
#                                                   title  \
# 0     A Pooled Single-Cell Genetic Screen Identifies...
# 1     Heterogeneity Of Human Bone Marrow And Blood N...
# 2     Single-Cell Transcriptomics Reveals Multi-Step...
# 3     Complex Oscillatory Waves Emerging From Cortic...
# 4     Single-Cell Analysis Of Crohn'S Disease Lesion...
# 5     Data Denoising With Transfer Learning In Singl...
# 6                                    Position Β57 Of I-
# 7     Identification Of Somatic Mutations In Single ...
# 8     Liquid Biopsy-Based Single-Cell Metabolic Phen...
# 9     Single-Cell Profiling Guided Combinatorial Imm...
# 10    B1 Oligomerization Regulates Pml Nuclear Body ...
# 11    The Malaria Cell Atlas: Single Parasite Transc...
# 12    Conserved Cell Types With Divergent Features I...
# 13    Reconstituting The Transcriptome And Dna Methy...
# 14    Metabolic Landscape Of The Tumor Microenvironm...
# 15    Molecular Mechanisms Of Lineage Decisions In M...
# 16    Mapping Histone Modifications In Low Cell Numb...
# 17    Defining The Identity And Dynamics Of Adult Ga...
# 18    Single Cell Transcriptome Analysis Of Developi...
# 19    Dissecting The Heterogeneity Of Denv Vaccine-E...
# 20    A General Approach For Detecting Expressed Mut...
# 21                    A Dream Of Single-Cell Proteomics
# 22    An Nfil3-Zeb2-Id2 Pathway Imposes Irf8 Enhance...
# 23    Single-Cell Dna Replication Profiling Identifi...
# 24    Exploring Genetic Interaction Manifolds Constr...
# 25    A Single-Cell Window Into Pancreas Cancer Fibr...
# 26    Cell-Type-Specific Resolution Epigenetics With...
# 27    Gene Expression Atlas Of A Developing Tissue B...
# 28    The Transcription Factor Tcf-1 Enforces Commit...
# 29    Single-Cell Cas-Seq Reveals A Class Of Short P...
# ...                                                 ...
# 1422  Control of cytokinesis by β-adrenergic recepto...
# 1423  Resolving the fibrotic niche of human liver ci...
# 1424  SCALE method for single-cell ATAC-seq analysis...
# 1425  Dissecting splicing decisions and cell-to-cell...
# 1426  Stereotyped transcriptomic transformation of s...
# 1427  Multiplex live single-cell transcriptional ana...
# 1428  Single-cell immune landscape of human atherosc...
# 1429  Exploring single-cell data with deep multitask...
# 1430                            Locally instructed CXCR
# 1431  Tumor Cell Biodiversity Drives Microenvironmen...
# 1432  Cell Type Purification by Single-Cell Transcri...
# 1433  Microglia Biology: One Century of Evolving Con...
# 1434  Single cell transcriptome in aneuploidies reve...
# 1435  Single-Cell RNA Sequencing Reveals a Developme...
# 1436  Single-Cell Reconstruction of Emerging Populat...
# 1437  Human Germline Cell Development: from the Pers...
# 1438  Single-cell transcriptomic profiling of the ag...
# 1439  Mitigating Antagonism between Transcription an...
# 1440  Valid Post-clustering Differential Analysis fo...
# 1441  Probabilistic cell-type assignment of single-c...
# 1442  Simultaneous profiling of 3D genome structure ...
# 1443  FRET-assisted photoactivation of flavoproteins...
# 1444  Supervised classification enables rapid annota...
# 1445     Supervised clustering for single-cell analysis
# 1446  Complex Oscillatory Waves Emerging from Cortic...
# 1447  CoBATCH for High-Throughput Single-Cell Epigen...
# 1448  CRISPR Interference-Based Platform for Multimo...
# 1449  Neuropeptide CGRP Limits Group 2 Innate Lympho...
# 1450  Epigenomics and Single-Cell Sequencing Define ...
# 1451  Stress-Induced Changes in Bone Marrow Stromal ...
#
#                              journal pubmed_id  \
# 0                    Nature genetics  31477929
# 1              Nature communications  31477722
# 2              Nature communications  31477698
# 3                     Cell stem cell  31474560
# 4                               Cell  31474370
# 5                     Nature methods  31471617
# 6                 Science immunology  31471352
# 7              Nature communications  31467286
# 8              Nature communications  31451693
# 9              Nature communications  31444334
# 10             Nature communications  31439836
# 11          Science (New York, N.Y.)  31439762
# 12                            Nature  31435019
# 13                            Nature  31435013
# 14             Nature communications  31434891
# 15                 Nature immunology  31431722
# 16             Nature communications  31431618
# 17                    Cell stem cell  31422913
# 18             Nature communications  31420539
# 19             Nature communications  31413301
# 20             Nature communications  31413257
# 21                    Nature methods  31406385
# 22                 Nature immunology  31406377
# 23                   Nature genetics  31406346
# 24          Science (New York, N.Y.)  31395745
# 25                  Cancer discovery  31371323
# 26             Nature communications  31366909
# 27                    Nature methods  31363221
# 28                 Nature immunology  31358996
# 29             Nature communications  31358756
# ...                              ...       ...
# 1422  Science translational medicine  31597755
# 1423                          Nature  31597160
# 1424           Nature communications  31594952
# 1425           Nature communications  31594945
# 1426                           eLife  31592768
# 1427                           eLife  31591966
# 1428                 Nature medicine  31591603
# 1429                  Nature methods  31591579
# 1430               Nature immunology  31591573
# 1431                     Cancer cell  31588021
# 1432                            Cell  31585086
# 1433                            Cell  31585077
# 1434           Nature communications  31582743
# 1435                Cancer discovery  31575563
# 1436                            Cell  31564455
# 1437                  Molecular cell  31563431
# 1438             Nature neuroscience  31551601
# 1439                  Cell stem cell  31523028
# 1440                    Cell systems  31521605
# 1441                  Nature methods  31501550
# 1442                  Nature methods  31501549
# 1443                  Nature methods  31501546
# 1444                  Nature methods  31501545
# 1445                  Nature methods  31501544
# 1446                  Cell stem cell  31474560
# 1447                  Molecular cell  31471188
# 1448                          Neuron  31422865
# 1449                        Immunity  31353223
# 1450                Cancer discovery  31345789
# 1451                  Cell stem cell  31279774
#
#                                                   gseID
# 0                                          notAvailable
# 1                                             GSE130430
# 2                                             GSE122743
# 3                                          notAvailable
# 4                                          notAvailable
# 5                                          notAvailable
# 6                                          notAvailable
# 7                                          notAvailable
# 8                                          notAvailable
# 9                                             GSE122336
# 10                                         notAvailable
# 11                                         notAvailable
# 12                                         notAvailable
# 13                                            GSE109555
# 14                                         notAvailable
# 15                                         notAvailable
# 16                                            GSE125971
# 17                                         notAvailable
# 18                                            GSE126480
# 19                                            GSE132950
# 20                                         notAvailable
# 21                                         notAvailable
# 22                                         notAvailable
# 23                                         notAvailable
# 24                                         notAvailable
# 25                                         notAvailable
# 26                                            GSE131989
# 27                                            GSE127832
# 28                                            GSE128483
# 29                                            GSE095218
# ...                                                 ...
# 1422                                       notAvailable
# 1423                                          GSE036103
# 1424                                       notAvailable
# 1425                                          GSE032064
# 1426                                          GSE031272
# 1427                                       notAvailable
# 1428                                       notAvailable
# 1429                                       notAvailable
# 1430                                       notAvailable
# 1431                                          GSE025449
# 1432                                          GSE012438
# 1433                                       notAvailable
# 1434                                GSE035500_GSE023028
# 1435                                       notAvailable
# 1436                                       notAvailable
# 1437                                       notAvailable
# 1438                                          GSE029788
# 1439                                       notAvailable
# 1440                                       notAvailable
# 1441                                       notAvailable
# 1442                                GSE030711_GSE024391
# 1443                                       notAvailable
# 1444                                       notAvailable
# 1445                                       notAvailable
# 1446                                       notAvailable
# 1447  GSE032846_GSE032844_GSE029335_GSE029333_GSE029...
# 1448                                       notAvailable
# 1449                                          GSE031996
# 1450                      GSE033785_GSE033706_GSE033704
# 1451                                          GSE031305
#
# [1452 rows x 4 columns]

# %%
new_list.to_csv(NEW_LIST_DIR, header='column_names', sep=',')
